# %%
import numpy as np

# %%
arr = np.array([23,53,867,12,4,75,23,6,53])

# %%
int(np.mean(arr))
# Out:
# 124

# %%
int(np.std(arr))
# Out:
# 263

# %%
np.var(arr)
# Out:
# np.float64(69533.55555555556)

# %%
np.min(arr),np.max(arr)
# Out:
# (np.int64(4), np.int64(867))

# %%
np.sum(arr),np.prod(arr)
# Out:
# (np.int64(1116), np.int64(27827888839200))

# %%
np.percentile(arr, 50)  # For the 50th percentile (median)
# Out:
# np.float64(23.0)

# %%
np.argmin(arr) # Return the index of the minimum value in an array.
# Out:
# np.int64(4)

# %%
np.argmax(arr) # Return the index of the maximum value in an array.
# Out:
# np.int64(2)

# %%
# np.corrcoef(arr1, arr2) # Compute the correlation coefficient matrix of two arrays.

# %%
np.unique(arr) # Find the unique elements of an array.
# Out:
# array([  4,   6,  12,  23,  53,  75, 867])

# %%
np.diff(arr)
# Out:
# array([  30,  814, -855,   -8,   71,  -52,  -17,   47])

# %%
np.cumsum(arr) #Compute the cumulative sum of an array.
# Out:
# array([  23,   76,  943,  955,  959, 1034, 1057, 1063, 1116])

# %%
np.linspace(0, 10, 5)  # 5 numbers from 0 to 10
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.log(arr)
# Out:
# array([3.13549422, 3.97029191, 6.76503898, 2.48490665, 1.38629436,
#        4.31748811, 3.13549422, 1.79175947, 3.97029191])

# %%
# np.exp(arr)
